# %%
import sparknlp
sparknlp.start()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-2-438c49067f23> in <module>
#       1 import sparknlp
# ----> 2 sparknlp.start()
#
# D:\py-related\anaconda\envs\git-conda38\lib\site-packages\sparknlp\__init__.py in start(gpu, spark23, spark24, spark32, memory, cache_folder, log_folder, cluster_tmp_dir, real_time_output, output_level)
#     271             return SparkRealTimeOutput()
#     272     else:
# --> 273         spark_session = start_without_realtime_output()
#     274         return spark_session
#     275
#
# D:\py-related\anaconda\envs\git-conda38\lib\site-packages\sparknlp\__init__.py in start_without_realtime_output()
#     175             builder.config("spark.jsl.settings.storage.cluster_tmp_dir", cluster_tmp_dir)
#     176
# --> 177         return builder.getOrCreate()
#     178
#     179     def start_with_realtime_output():
#
# ...
